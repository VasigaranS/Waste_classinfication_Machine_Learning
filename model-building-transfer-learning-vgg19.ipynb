# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt
import os

# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score 
import os
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Flatten,Dense
from tensorflow.keras.applications import resnet50

# %%
image_size=32
batch_size=256

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory('/kaggle/input/waste-classification-data/DATASET/TRAIN/',shuffle=True,image_size=(image_size,image_size),batch_size=batch_size)
test_dataset=tf.keras.preprocessing.image_dataset_from_directory('/kaggle/input/waste-classification-data/DATASET/TEST/',shuffle=True,image_size=(image_size,image_size),batch_size=batch_size)
# Out:
# Found 22564 files belonging to 2 classes.
# Found 2513 files belonging to 2 classes.

# %%
len(dataset)*0.80
# Out:
# 71.2

# %%
dataset=dataset.shuffle(100000,seed=20)

# %%
train_ds=dataset.take(71)

# %%
len(train_ds)
# Out:
# 71

# %%
val_ds=dataset.skip(71)

# %%
len(val_ds)
# Out:
# 18

# %%
len(test_dataset)
# Out:
# 10

# %%
#prefetch to read faster gpu trains and cpu fetches next batch
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset=test_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
def train_model_feature_extraction(lr,epochs):
    pretrained_model= tf.keras.applications.VGG19(include_top=False,
                   input_shape=(image_size,image_size,3),
                   #pooling='avg',
                   weights='imagenet')
    print("Number of layers in the base model: ", len(pretrained_model.layers))

    pretrained_model.trainable = False
    pretrained_model.summary()
    VGG19_model_frozen = Sequential()
    pretrained_model.trainable = False
    #for layer in pretrained_model.layers[:11]:
        #layer.trainable = False


    #for layer in pretrained_model.layers[:-1]: # go through until last layer
        #resnet_model.add(layer)


    #resnet_model.add(tf.keras.layers.BatchNormalization(renorm=True))
    VGG19_model_frozen.add(pretrained_model)
    #resnet_model.add(tf.keras.layers.BatchNormalization())
    VGG19_model_frozen.add(Flatten())

    prediction_layer = tf.keras.layers.Dense(2, activation='softmax')
    VGG19_model_frozen.add(prediction_layer)

    #model.compile(optimizer='adam', loss='categorical_crossentropy')
    for i, layer in enumerate(pretrained_model.layers):
            print(i, layer.name, "-", layer.trainable)
            
    opt = Adam(learning_rate=lr)
    VGG19_model_frozen.compile(optimizer=opt,loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),metrics=['accuracy'])
    history=VGG19_model_frozen.fit(train_ds,epochs=epochs,batch_size=256,verbose=1,validation_data=val_ds)
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()),1])
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0,5.0])
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()
    scores=VGG19_model_frozen.evaluate(test_dataset)
    print(scores)

# %%
train_model_feature_extraction(0.001,20)
# Out:
# Number of layers in the base model:  22
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________
# 0 input_6 - False
# 1 block1_conv1 - False
# 2 block1_conv2 - False
# 3 block1_pool - False
# 4 block2_conv1 - False
# 5 block2_conv2 - False
# 6 block2_pool - False
# 7 block3_conv1 - False
# 8 block3_conv2 - False
# 9 block3_conv3 - False
# 10 block3_conv4 - False
# 11 block3_pool - False
# 12 block4_conv1 - False
# 13 block4_conv2 - False
# 14 block4_conv3 - False
# 15 block4_conv4 - False
# 16 block4_pool - False
# 17 block5_conv1 - False
# 18 block5_conv2 - False
# 19 block5_conv3 - False
# 20 block5_conv4 - False
# 21 block5_pool - False
# Epoch 1/20
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# 2022-10-11 11:09:51.769761: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 69 of 100000
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
#  4/71 [>.............................] - ETA: 1s - loss: 20.8407 - accuracy: 0.4238
# Cleanup called...
# 2022-10-11 11:09:53.247083: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 2022-10-11 11:09:53.247141: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 1 of 1000
# 2022-10-11 11:09:53.247776: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 70/71 [============================>.] - ETA: 0s - loss: 6.6635 - accuracy: 0.6935
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# 2022-10-11 11:10:04.893162: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 65 of 100000
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# 2022-10-11 11:10:07.142729: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 2022-10-11 11:10:07.143036: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 1 of 1000
# 2022-10-11 11:10:07.143574: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 71/71 [==============================] - 26s 204ms/step - loss: 6.6185 - accuracy: 0.6944 - val_loss: 3.2973 - val_accuracy: 0.7785
# Epoch 2/20
# 71/71 [==============================] - 2s 25ms/step - loss: 2.7464 - accuracy: 0.7785 - val_loss: 2.1184 - val_accuracy: 0.7963
# Epoch 3/20
# 71/71 [==============================] - 2s 25ms/step - loss: 1.8800 - accuracy: 0.7905 - val_loss: 1.4770 - val_accuracy: 0.8052
# Epoch 4/20
# 71/71 [==============================] - 2s 25ms/step - loss: 1.3452 - accuracy: 0.7992 - val_loss: 1.0876 - val_accuracy: 0.8088
# Epoch 5/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.9844 - accuracy: 0.8051 - val_loss: 0.8404 - val_accuracy: 0.8131
# Epoch 6/20
# 71/71 [==============================] - 2s 26ms/step - loss: 0.7345 - accuracy: 0.8126 - val_loss: 0.6146 - val_accuracy: 0.8131
# Epoch 7/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.5602 - accuracy: 0.8193 - val_loss: 0.4968 - val_accuracy: 0.8236
# Epoch 8/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4612 - accuracy: 0.8286 - val_loss: 0.4301 - val_accuracy: 0.8307
# Epoch 9/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4382 - accuracy: 0.8263 - val_loss: 0.3923 - val_accuracy: 0.8398
# Epoch 10/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4096 - accuracy: 0.8338 - val_loss: 0.3815 - val_accuracy: 0.8400
# Epoch 11/20
# 71/71 [==============================] - 2s 26ms/step - loss: 0.4123 - accuracy: 0.8295 - val_loss: 0.4790 - val_accuracy: 0.8090
# Epoch 12/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4199 - accuracy: 0.8326 - val_loss: 0.3875 - val_accuracy: 0.8387
# Epoch 13/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4171 - accuracy: 0.8324 - val_loss: 0.4252 - val_accuracy: 0.8138
# Epoch 14/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4117 - accuracy: 0.8343 - val_loss: 0.3937 - val_accuracy: 0.8352
# Epoch 15/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4092 - accuracy: 0.8316 - val_loss: 0.4495 - val_accuracy: 0.8234
# Epoch 16/20
# 71/71 [==============================] - 2s 26ms/step - loss: 0.4245 - accuracy: 0.8268 - val_loss: 0.3871 - val_accuracy: 0.8357
# Epoch 17/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4086 - accuracy: 0.8310 - val_loss: 0.3901 - val_accuracy: 0.8446
# Epoch 18/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4279 - accuracy: 0.8294 - val_loss: 0.4013 - val_accuracy: 0.8298
# Epoch 19/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4154 - accuracy: 0.8307 - val_loss: 0.4002 - val_accuracy: 0.8382
# Epoch 20/20
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4059 - accuracy: 0.8373 - val_loss: 0.3997 - val_accuracy: 0.8250
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
#  7/10 [====================>.........] - ETA: 0s - loss: 0.5630 - accuracy: 0.8092
# Cleanup called...
# Cleanup called...
# 10/10 [==============================] - 2s 20ms/step - loss: 0.5718 - accuracy: 0.8126
# [0.571788489818573, 0.8125746250152588]

# %%
def train_model_fine_tuning(lr,epochs):
    pretrained_model= tf.keras.applications.VGG19(include_top=False,
                   input_shape=(image_size,image_size,3),
                   #pooling='avg',
                   weights='imagenet')
    print("Number of layers in the base model: ", len(pretrained_model.layers))

    
    pretrained_model.summary()
    VGG19_model_frozen = Sequential()
    pretrained_model.trainable = True
    for layer in pretrained_model.layers[:7]:
        layer.trainable = False


    #for layer in pretrained_model.layers[:-1]: # go through until last layer
        #resnet_model.add(layer)


    #resnet_model.add(tf.keras.layers.BatchNormalization(renorm=True))
    VGG19_model_frozen.add(pretrained_model)
    #resnet_model.add(tf.keras.layers.BatchNormalization())
    VGG19_model_frozen.add(Flatten())

    prediction_layer = tf.keras.layers.Dense(2, activation='softmax')
    VGG19_model_frozen.add(prediction_layer)

    #model.compile(optimizer='adam', loss='categorical_crossentropy')
    for i, layer in enumerate(pretrained_model.layers):
            print(i, layer.name, "-", layer.trainable)
            
    opt = Adam(learning_rate=lr)
    VGG19_model_frozen.compile(optimizer=opt,loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),metrics=['accuracy'])
    history=VGG19_model_frozen.fit(train_ds,epochs=epochs,batch_size=256,verbose=1,validation_data=val_ds)
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()),1])
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0,5.0])
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()
    scores=VGG19_model_frozen.evaluate(test_dataset)
    print(scores)

# %%
train_model_fine_tuning(0.001,20)
# Out:
# Number of layers in the base model:  22
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________
# 0 input_11 - False
# 1 block1_conv1 - False
# 2 block1_conv2 - False
# 3 block1_pool - False
# 4 block2_conv1 - False
# 5 block2_conv2 - False
# 6 block2_pool - False
# 7 block3_conv1 - True
# 8 block3_conv2 - True
# 9 block3_conv3 - True
# 10 block3_conv4 - True
# 11 block3_pool - True
# 12 block4_conv1 - True
# 13 block4_conv2 - True
# 14 block4_conv3 - True
# 15 block4_conv4 - True
# 16 block4_pool - True
# 17 block5_conv1 - True
# 18 block5_conv2 - True
# 19 block5_conv3 - True
# 20 block5_conv4 - True
# 21 block5_pool - True
# Epoch 1/20
# 71/71 [==============================] - 5s 58ms/step - loss: 6.0690 - accuracy: 0.5785 - val_loss: 0.5792 - val_accuracy: 0.7056
# Epoch 2/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.4839 - accuracy: 0.7714 - val_loss: 0.4471 - val_accuracy: 0.7899
# Epoch 3/20
# 71/71 [==============================] - 4s 56ms/step - loss: 0.4417 - accuracy: 0.8025 - val_loss: 0.4018 - val_accuracy: 0.8343
# Epoch 4/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.3928 - accuracy: 0.8288 - val_loss: 0.4232 - val_accuracy: 0.8170
# Epoch 5/20
# 71/71 [==============================] - 4s 56ms/step - loss: 0.3709 - accuracy: 0.8406 - val_loss: 0.3468 - val_accuracy: 0.8585
# Epoch 6/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.3704 - accuracy: 0.8417 - val_loss: 0.3376 - val_accuracy: 0.8633
# Epoch 7/20
# 71/71 [==============================] - 4s 56ms/step - loss: 0.3516 - accuracy: 0.8502 - val_loss: 0.3333 - val_accuracy: 0.8612
# Epoch 8/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.3399 - accuracy: 0.8581 - val_loss: 0.3237 - val_accuracy: 0.8667
# Epoch 9/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.3338 - accuracy: 0.8605 - val_loss: 0.3234 - val_accuracy: 0.8676
# Epoch 10/20
# 71/71 [==============================] - 4s 57ms/step - loss: 0.3222 - accuracy: 0.8666 - val_loss: 0.3046 - val_accuracy: 0.8794
# Epoch 11/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.3168 - accuracy: 0.8696 - val_loss: 0.3862 - val_accuracy: 0.8154
# Epoch 12/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.3132 - accuracy: 0.8709 - val_loss: 0.2943 - val_accuracy: 0.8838
# Epoch 13/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.2959 - accuracy: 0.8795 - val_loss: 0.2977 - val_accuracy: 0.8797
# Epoch 14/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.2929 - accuracy: 0.8809 - val_loss: 0.2807 - val_accuracy: 0.8876
# Epoch 15/20
# 71/71 [==============================] - 4s 56ms/step - loss: 0.2843 - accuracy: 0.8857 - val_loss: 0.2782 - val_accuracy: 0.8856
# Epoch 16/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.2816 - accuracy: 0.8850 - val_loss: 0.2790 - val_accuracy: 0.8861
# Epoch 17/20
# 71/71 [==============================] - 4s 56ms/step - loss: 0.2820 - accuracy: 0.8847 - val_loss: 0.3013 - val_accuracy: 0.8719
# Epoch 18/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.2675 - accuracy: 0.8933 - val_loss: 0.3500 - val_accuracy: 0.8439
# Epoch 19/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.2687 - accuracy: 0.8918 - val_loss: 0.2929 - val_accuracy: 0.8772
# Epoch 20/20
# 71/71 [==============================] - 4s 55ms/step - loss: 0.2546 - accuracy: 0.8978 - val_loss: 0.2470 - val_accuracy: 0.9038
# 10/10 [==============================] - 0s 20ms/step - loss: 0.2552 - accuracy: 0.8961
# [0.25524231791496277, 0.8961400985717773]
